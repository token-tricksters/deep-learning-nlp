# %% [markdown]
# # Assignment 06 - LM and RNN

# %%
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1k4IFWScWnD3senYOUeVQFRv-6bOsmwWY' -O gdata.zip
# !unzip -q gdata.zip

# %% [markdown]
# # Exercises

# %% [markdown]
# ## Part A

# %% [markdown]
# 1. Using another corpus let's try to create a more interesting language model. Use the corpus in `data\gdata\2016-us-presidential-debates.zip` (the person and text column) and let's see if we can create a candidate with an interesting dialect.
#     * Do some pre-processing before transforming  your text into number
#     * Use a different activation function
#     * Use different dimensions in your embeddings
#     * Use a different kernel initializer
#     * Use a different optimizers
#     * Use a different number of epochs
#     * Consider a larger Buffer and batch size
#      * Text normalization, punctuation and stop word removal, etc
#
# Provide a start string and generate your text for the next 2000 chars chars. Who your candidate sound like? Save your mode to use later (*laboratory 07*). If you have time produce two models with different pre-processing/configuration.
#
# Specify the architecture and the configuration used for your model. Including how your input was (pre)processed. How many epcohs were necessary so your language model would look like a candidate?
#
# Remember anyone should be able to reproduce your results!

# %% [markdown]
# ##### Acknowledgements
# Names.
